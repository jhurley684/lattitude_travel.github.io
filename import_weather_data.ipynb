# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load: ('resources/purchase_data.csv')

# Read Purchasing File and store into Pandas data frame
weather_data = pd.read_csv("instructions/resources/cities.csv")
weather_data_df = pd.DataFrame(weather_data)

# %%
# Display data preview for easy reference

weather_data_df = weather_data_df[["City","Cloudiness","Country","Date","Humidity", "Lat","Lng","Max Temp", "Wind Speed", "Date - Time"]]
weather_data_df
# Out:
#              City Cloudiness  Country        Date Humidity      Lat      Lng  \
# 0         Column1    Column2  Column3     Column4  Column5  Column6  Column7
# 1    jacareacanga          0       BR  1528902000       62    -6.22   -57.76
# 2      kaitangata        100       NZ  1528905304       94   -46.28   169.85
# 3        goulburn         20       AU  1528905078       91   -34.75   149.72
# 4            lata         76       IN  1528905305       89    30.78    78.62
# ..            ...        ...      ...         ...      ...      ...      ...
# 543        scalea         36       IT  1528905631      100    39.82    15.79
# 544    san andres         68       PH  1528905632      100    13.32   122.68
# 545        muisne         92       EC  1528905633       84     0.61   -80.02
# 546           ati         20       TD  1528905633       25    13.21    18.34
# 547      san luis          0       AR  1528905472       53    -33.3   -66.34
#
#     Max Temp Wind Speed      Date - Time
# ...

# %%
# dropping the 0th and the 1st index

# resetting the DataFrame index
# weather_data_df
weather_data_df.reset_index()
weather_data_df = weather_data_df.iloc[1: , :]
weather_data_df
# Out:
#              City Cloudiness Country        Date Humidity     Lat     Lng  \
# 1    jacareacanga          0      BR  1528902000       62   -6.22  -57.76
# 2      kaitangata        100      NZ  1528905304       94  -46.28  169.85
# 3        goulburn         20      AU  1528905078       91  -34.75  149.72
# 4            lata         76      IN  1528905305       89   30.78   78.62
# 5      chokurdakh          0      RU  1528905306       88   70.62   147.9
# ..            ...        ...     ...         ...      ...     ...     ...
# 543        scalea         36      IT  1528905631      100   39.82   15.79
# 544    san andres         68      PH  1528905632      100   13.32  122.68
# 545        muisne         92      EC  1528905633       84    0.61  -80.02
# 546           ati         20      TD  1528905633       25   13.21   18.34
# 547      san luis          0      AR  1528905472       53   -33.3  -66.34
#
#     Max Temp Wind Speed      Date - Time
# ...

# %%
html = weather_data_df.to_html()

# %%
# write html to file
text_file = open("weather_data.html", "w")
text_file.write(html)
text_file.close()
